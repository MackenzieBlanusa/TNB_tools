# %% [markdown]
# ### Create Data Tree
#
# This notebook create a data tree with mooring data

# %%
# import packages 
import xarray as xr 
import matplotlib as plt 
import numpy as np 
import os as os

# %%
# make below cell into a function 
def open_ncfiles_in_directory(directory):
        """
        Docstring for open_ncfiles_in_directory
        
        :param directory: Description
        """
        varnames=[]
        for filename in os.listdir(directory):
            if filename.endswith(".nc"):
                file=os.path.splitext(os.path.basename(filename))[0]
                varnames.append(file)

        for name in varnames:
            globals()[name] = xr.open_dataset(directory+'/'+name+'.nc')
            print(name);

        print(f"\nLoaded {len(varnames)} NetCDF files")

# %%
# currently loading in 166 data files!! 

open_ncfiles_in_directory(directory = '//thepenguin/penguin2/Data/TNB/mooring/Mooring_D_MORSea/Mooring_D_2014_2025/working')
open_ncfiles_in_directory(directory = '//thepenguin/penguin2/Data/TNB/mooring/RossSeaOutflow/P2/working')
open_ncfiles_in_directory(directory = '//thepenguin/penguin2/Data/TNB/mooring/RossSeaOutflow/P3/working')
open_ncfiles_in_directory(directory = '//thepenguin/penguin2/Data/TNB/mooring/DITx/DITD/working')
open_ncfiles_in_directory(directory = '//thepenguin/penguin2/Data/TNB/mooring/DITx/DITN/working')
open_ncfiles_in_directory(directory = '//thepenguin/penguin2/Data/TNB/mooring/DITx/DITS/working')
open_ncfiles_in_directory(directory = '//thepenguin/penguin2/Data/TNB/mooring/LDEO/TNBD_2018/working')
open_ncfiles_in_directory(directory = '//thepenguin/penguin2/Data/TNB/mooring/LDEO/LDEO_2017_QC/working')

# open_ncfiles_in_directory(directory = '/Users/mackenzie/Documents/Research/PhD/TNB_Research/data/moorings/DITN')
# open_ncfiles_in_directory(directory = '/Users/mackenzie/Documents/Research/PhD/TNB_Research/data/moorings/DITS')
# open_ncfiles_in_directory(directory = '/Users/mackenzie/Documents/Research/PhD/TNB_Research/data/moorings/P2')
# open_ncfiles_in_directory(directory = '/Users/mackenzie/Documents/Research/PhD/TNB_Research/data/moorings/P3')
# open_ncfiles_in_directory(directory = '/Users/mackenzie/Documents/Research/PhD/TNB_Research/data/moorings/TNBD')
# Out:
# D_2014_ctd_bot
# D_2014_ctd_top
# D_2014_temp_mid1
# D_2014_temp_mid2
# D_2014_vel_bot
# D_2014_vel_mid
# D_2014_vel_top
# D_2016_ctd_bot
# D_2016_ctd_top
# D_2016_temp_mid1
# D_2016_temp_mid2
# D_2016_vel_bot
# D_2017_ctd_bot
# D_2017_ctd_mid1
# D_2017_ctd_top
# D_2017_temp_mid2
# D_2017_vel_bot
# D_2017_vel_mid
# D_2017_vel_top
# D_2019_ctd_bot
# D_2019_ctd_mid1
# D_2019_ctd_top
# D_2019_temp_mid2
# D_2019_vel_bot
# D_2019_vel_mid
# D_2019_vel_top
# D_2020_ctd_mid2
# D_2020_ctd_top
# D_2020_temp_mid1
# D_2021_ctd_bot
# D_2021_ctd_mid1
# D_2021_ctd_top
# D_2021_temp_mid2
# D_2021_vel_bot
# D_2021_vel_mid
# D_2021_vel_top
# D_2022_ctd_mid1
# D_2022_ctd_top
# D_2022_temp_mid2
# D_2022_vel_mid
# D_2022_vel_top
# D_2023_ctd_bot
# D_2023_ctd_mid1
# D_2023_temp_mid2
# D_2023_vel_bot
# D_2023_vel_mid
# D_2024_ctd_bot
# D_2024_ctd_mid1
# D_2024_temp_mid2
# D_2024_vel_bot
# D_2024_vel_mid
#
# Loaded 51 NetCDF files
# P2_2018_ctd_bot_1692
# P2_2018_ctd_mid_1440
# P2_2018_ctd_top_1262
# ...

# %%
# time is messed up on DITS, I will make my own time axis for now and will confirm this issue with Liv 
# start: 12/2/2017, end: 8/03/2018, dt = 600s
start = np.datetime64('2017-02-12T12')
end   = np.datetime64('2018-03-08T14:00:00')
dt    = np.timedelta64(600, 's')  # 600 seconds = 10 minutes

time = np.arange(start, end + dt, dt)

# %%
time
# Out:
# array(['2017-02-12T12:00:00', '2017-02-12T12:10:00',
#        '2017-02-12T12:20:00', ..., '2018-03-08T13:40:00',
#        '2018-03-08T13:50:00', '2018-03-08T14:00:00'],
#       shape=(56029,), dtype='datetime64[s]')

# %%
DITS_2017 = DITS_2017_ctd_bot_1088.dropna(dim='time')

# %%
DITS_2017['time'] = time

# %%
DITS_2017_ctd_bot_1088 = DITS_2017

# %%
DITD_2018_ctd_bot = DITD_2018_ctd_bot.dropna(dim='time')
DITN_2018_vel_bot_666 = DITN_2018_vel_bot_666.dropna(dim='time')

# %%
DITD_dict = {
    "/": None,

    "2017/vel/bot": DITD_2017_vel_bot,
    "2018/vel/top": DITD_2018_vel_top,
    "2018/vel/bot": DITD_2018_vel_bot,
    "2019/vel/bot": DITD_2019_vel_bot,
    "2020/vel/bot": DITD_2020_vel_bot,
    "2022/vel/bot": DITD_2022_vel_bot,
    "2024/vel/bot": DITD_2024_vel_bot,
    
    "2017/ctd/bot": DITD_2017_ctd_bot,
    "2018/ctd/top": DITD_2018_ctd_top,
    "2018/ctd/bot": DITD_2018_ctd_bot,
    "2019/ctd/bot": DITD_2019_ctd_bot,
    "2020/ctd/bot": DITD_2020_ctd_bot,
    "2022/ctd/bot": DITD_2022_ctd_bot,
    "2024/ctd/bot": DITD_2024_ctd_bot,

}

# %%
dt_DITD = xr.DataTree.from_dict(DITD_dict)

# %%
dt_DITD
# Out:
# <xarray.DataTree>
# Group: /
# ├── Group: /2017
# │   ├── Group: /2017/vel
# │   │   └── Group: /2017/vel/bot
# │   │           Dimensions:  (time: 37488)
# │   │           Coordinates:
# │   │             * time     (time) datetime64[ns] 300kB 2017-02-08T20:30:00 ... 2018-03-06T0...
# │   │               z        int64 8B ...
# │   │               lat      float64 8B ...
# │   │               lon      float64 8B ...
# │   │           Data variables: (12/15)
# │   │               dir      (time) float64 300kB ...
# │   │               speed    (time) float64 300kB ...
# │   │               temp     (time) float64 300kB ...
# │   │               pres     (time) float64 300kB ...
# │   │               hdgt     (time) float64 300kB ...
# │   │               pitch    (time) float64 300kB ...
# │   │               ...       ...
# │   │               w        (time) float64 300kB ...
# │   │               volt     (time) float64 300kB ...
# ...

# %%
# Create dictionary for DITS
DITS_dict = {
    "/": None,
    "2017/vel/top": DITS_2017_speed_top_191,
    "2017/vel/mid": DITS_2017_speed_mid_384,
    "2017/vel/bot": DITS_2017_speed_bot_1087,
    "2018/vel/top": DITS_2018_vel_top_47,
    "2018/vel/mid": DITS_2018_vel_mid_220,
    "2018/vel/bot": DITS_2018_vel_bot_1027,

    "2017/ctd/top": DITS_2017_ctd_top_192,
    "2017/ctd/mid": DITS_2017_ctd_mid_383,
    "2017/ctd/bot": DITS_2017_ctd_bot_1088,
    "2018/ctd/top": DITS_2018_ctd_top_63,
    "2018/ctd/mid": DITS_2018_ctd_mid_208,
    "2018/ctd/bot": DITS_2018_ctd_bot_1458,

    "2017/temp/top": DITS_2017_temp_top_233,
    "2017/temp/mid": DITS_2017_temp_mid1_273,
    "2017/temp/mid1": DITS_2017_temp_mid2_313,
    "2017/temp/bot": DITS_2017_temp_bot_353,

    "2018/temp/top": DITS_2018_temp_top_88,
    "2018/temp/mid": DITS_2018_temp_mid1_128,
    "2018/temp/mid1": DITS_2018_temp_mid2_168,
    "2018/temp/bot": DITS_2018_temp_bot_208
}

# %%
dt_DITS = xr.DataTree.from_dict(DITS_dict)

# %%
dt_DITS
# Out:
# <xarray.DataTree>
# Group: /
# ├── Group: /2017
# │   ├── Group: /2017/vel
# │   │   ├── Group: /2017/vel/top
# │   │   │       Dimensions:  (time: 9338)
# │   │   │       Coordinates:
# │   │   │         * time     (time) datetime64[ns] 75kB 2017-02-12T13:00:00 ... 2018-03-08T14...
# │   │   │           z        int64 8B ...
# │   │   │           lat      float64 8B ...
# │   │   │           lon      float64 8B ...
# │   │   │       Data variables:
# │   │   │           dir      (time) float64 75kB ...
# │   │   │           speed    (time) float64 75kB ...
# │   │   │           u        (time) float64 75kB ...
# │   │   │           v        (time) float64 75kB ...
# │   │   │       Attributes:
# │   │   │           description:  Mooring DITS 1702 rcm9
# │   │   ├── Group: /2017/vel/mid
# │   │   │       Dimensions:  (time: 9338)
# │   │   │       Coordinates:
# │   │   │         * time     (time) datetime64[ns] 75kB 2017-02-12T13:00:00 ... 2018-03-08T14...
# ...

# %%
# NO DITN 2019 ctd bottom, 2020 ctd top 
DITN_dict = {
    "/": None,
    "2014/vel/top": DITN_2014_speed_top_75,
    "2014/vel/mid": DITN_2014_speed_mid_276,
    "2014/vel/bot": DITN_2014_speed_bot_674,
    "2015/vel/top": DITN_2015_speed_top_71,
    "2015/vel/mid": DITN_2015_speed_mid_273,
    "2015/vel/bot": DITN_2015_speed_bot_667,
    "2017/vel/top": DITN_2017_vel_top_76,
    "2017/vel/mid": DITN_2017_vel_mid_271,
    "2017/vel/bot": DITN_2017_vel_bot_694,
    "2018/vel/top": DITN_2018_vel_top_71,
    "2018/vel/mid": DITN_2018_vel_mid_263,
    "2018/vel/bot": DITN_2018_vel_bot_666,
    "2019/vel/top": DITN_2019_vel_top_67,
    "2019/vel/mid": DITN_2019_vel_mid_255,
    "2019/vel/bot": DITN_2019_vel_bot_649,
    "2020/vel/top": DITN_2020_vel_top_54,
    "2020/vel/mid": DITN_2020_vel_mid_252,
    "2020/vel/bot": DITN_2020_vel_bot_671,

    "2014/ctd/top": DITN_2014_ctd_top_77,
    "2014/ctd/mid": DITN_2014_ctd_mid_278,
    "2014/ctd/bot": DITN_2014_ctd_bot_667,
    "2015/ctd/top": DITN_2015_ctd_top_73,
    "2015/ctd/mid": DITN_2015_ctd_mid_275,
    "2015/ctd/bot": DITN_2015_ctd_bot_666,
    "2017/ctd/top": DITN_2017_ctd_top_75,
    "2017/ctd/mid": DITN_2017_ctd_mid_275,
    "2017/ctd/bot": DITN_2017_ctd_bot_675,
    "2018/ctd/top": DITN_2018_ctd_top_73,
    "2018/ctd/mid": DITN_2018_ctd_mid_274,
    "2018/ctd/bot": DITN_2018_ctd_bot_670,
    "2019/ctd/top": DITN_2019_ctd_top_71,
    "2019/ctd/mid": DITN_2019_ctd_mid_271,
    "2020/ctd/mid": DITN_2020_ctd_mid_269,
    "2020/ctd/bot": DITN_2020_ctd_bot_667,

    "2014/temp/top": DITN_2014_temp_top_108,
    "2014/temp/mid": DITN_2014_temp_mid1_148,
    "2014/temp/mid1": DITN_2014_temp_mid2_188,
    "2014/temp/bot": DITN_2014_temp_bot_228,
    "2015/temp/top": DITN_2015_temp_top_113,
    "2015/temp/mid": DITN_2015_temp_mid1_153,
    "2015/temp/mid1": DITN_2015_temp_mid2_193,
    "2015/temp/bot": DITN_2015_temp_bot_233,
    "2017/temp/top": DITN_2017_temp_top_197,
    "2017/temp/mid": DITN_2017_temp_mid_330,
    "2017/temp/bot": DITN_2017_temp_bot_360,
    "2018/temp/top": DITN_2018_temp_top_114,
    "2018/temp/mid": DITN_2018_temp_mid1_154,
    "2018/temp/mid1": DITN_2018_temp_mid2_194,
    "2018/temp/bot": DITN_2018_temp_bot_224,
    "2019/temp/top": DITN_2019_temp_top_112,
    "2019/temp/mid": DITN_2019_temp_mid1_152,
    "2019/temp/mid1": DITN_2019_temp_mid2_192,
    "2019/temp/bot": DITN_2019_temp_bot_232,
    "2020/temp/top": DITN_2020_temp_top_95,
    "2020/temp/mid": DITN_2020_temp_mid1_135,
    "2020/temp/mid1": DITN_2020_temp_mid2_175,
    "2020/temp/bot": DITN_2020_temp_bot_215,
    
}

# %%
dt_DITN = xr.DataTree.from_dict(DITN_dict)

# %%
TNBD_dict = {
    "/": None,
    "2018/vel/top": tnbd_2018_vel_top_999,
    "2018/vel/bot": tnbd_2018_vel_bot_1093,
    "2018/ctd/top": tnbd_2018_ctd_top_999,
    "2018/ctd/bot": tnbd_2018_ctd_bot_1093
}

# %%
dt_TNBD = xr.DataTree.from_dict(TNBD_dict)

# %%
# not adding in seaguard for now and mid depth thermistor data 
P2_dict = {
    "/": None,
    "2018/vel/top": P2_2018_vel_top_1263,
    "2018/ctd/top": P2_2018_ctd_top_1262,
    "2018/ctd/mid": P2_2018_ctd_mid_1440,
    "2018/ctd/bot": P2_2018_ctd_bot_1692
}

# %%
dt_P2 = xr.DataTree.from_dict(P2_dict)

# %%
P3_dict = {
    "/": None,
    "2018/vel/top": P3_2018_vel_top_1263,
    "2018/ctd/top": P3_2018_ctd_top_1262,
    "2018/ctd/mid": P3_2018_ctd_mid_1414,
    "2018/ctd/bot": P3_2018_ctd_bot_1667
}

# %%
dt_P3 = xr.DataTree.from_dict(P3_dict)

# %%
D_2016_ctd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 D_2016_ctd
#
# NameError: name 'D_2016_ctd' is not defined

# %%
D_dict = {
    "/": None,
    "2014/vel/top": D_2014_vel_top,
    "2014/vel/mid": D_2014_vel_mid,
    "2014/vel/bot": D_2014_vel_bot,
    "2016/vel/bot": D_2016_vel_bot,
    "2017/vel/top": D_2017_vel_top,
    "2017/vel/mid": D_2017_vel_mid,
    "2017/vel/bot": D_2017_vel_bot,
    "2019/vel/top": D_2019_vel_top,
    "2019/vel/mid": D_2019_vel_mid,
    "2019/vel/bot": D_2019_vel_bot,
    "2021/vel/top": D_2021_vel_top,
    "2021/vel/mid": D_2021_vel_mid,
    "2021/vel/bot": D_2021_vel_bot,
    "2022/vel/top": D_2022_vel_top,
    "2022/vel/mid": D_2022_vel_mid,
    "2023/vel/mid": D_2023_vel_mid,
    "2023/vel/bot": D_2023_vel_bot,
    "2024/vel/mid": D_2024_vel_mid,
    "2024/vel/bot": D_2024_vel_bot,

    "2014/ctd/top": D_2014_ctd_top,
    "2014/ctd/bot": D_2014_ctd_bot,
    "2016/ctd/top": D_2016_ctd_top,
    "2016/ctd/bot": D_2016_ctd_bot,
    "2017/ctd/top": D_2017_ctd_top,
    "2017/ctd/mid": D_2017_ctd_mid1,
    "2017/ctd/bot": D_2017_ctd_bot,
    "2019/ctd/top": D_2019_ctd_top,
    "2019/ctd/mid": D_2019_ctd_mid1,
    "2019/ctd/bot": D_2019_ctd_bot,
    "2020/ctd/top": D_2020_ctd_top,
    "2020/ctd/mid": D_2020_ctd_mid2,
    "2021/ctd/top": D_2021_ctd_top,
    "2021/ctd/mid": D_2021_ctd_mid1,
    "2021/ctd/bot": D_2021_ctd_bot,
    "2022/ctd/top": D_2022_ctd_top,
    "2022/ctd/mid": D_2022_ctd_mid1,
    "2023/ctd/mid": D_2023_ctd_mid1,
    "2023/ctd/bot": D_2023_ctd_bot,
    "2024/ctd/mid": D_2024_ctd_mid1,
    "2024/ctd/bot": D_2024_ctd_bot


}

# add in temp data later

# %%
dt_D = xr.DataTree.from_dict(D_dict)

# %%
# need to select top and mid sensors to pair with DITN levels
# select 95 and 360 

LDEO_2017_ctd_top = LDEO_TNB_temperature_salinity.sel(depth=95)
LDEO_2017_ctd_bot = LDEO_TNB_temperature_salinity.sel(depth=360)
LDEO_2017_vel_bot = LDEO_TNB_370m_current_velocity

# %%
LDEO_datasets = [LDEO_2017_ctd_top, LDEO_2017_ctd_bot, LDEO_2017_vel_bot]

# %%
LDEO_datasets[2]
# Out:
# <xarray.Dataset> Size: 2MB
# Dimensions:   (time: 38094)
# Coordinates:
#   * time      (time) datetime64[ns] 305kB 2017-02-01T12:00:00 ... 2018-03-05T...
# Data variables:
#     east      (time) float64 305kB ...
#     north     (time) float64 305kB ...
#     up        (time) float64 305kB ...
#     pressure  (time) float64 305kB ...
# Attributes:
#     Institution:     Lamont-Doherty Earth Observatory
#     Contact:         zappa@ldeo.columbia.edu, ukm2103@columbia.edu
#     DOI:             doi:10.7916/a4k3-0a14
#     Instrument:      Aquadopp Current Meter 2000 kHz
#     Location:        Terra Nova Bay, Antarctica
#     Mooring_coords:  74.97° S, 163.96° E
#     Units:           Velocity: m/s, Pressure:dbar
#     Depth:           370 m
#     Notes:           Horizontal current velocities should be multiplied by -c...

# %%
# Create function for renaming dimensions 

def rename_vars_if_exist(ds, rename_map):
    """
    Rename variables in an xarray Dataset only if they exist.

    Parameters
    ----------
    ds : xr.Dataset
        Input dataset
    rename_map : dict
        Mapping {old_name: new_name}

    Returns
    -------
    xr.Dataset
        Dataset with variables renamed where applicable
    """
    existing = {old: new for old, new in rename_map.items() if old in ds.data_vars}
    return ds.rename(existing)

# %%
rename_map = {
    "temperature_insitu": "temp",
    "potential_temperature": "theta",
    "conductivity": "con",
    "practical_salinity": "sal",
    "pressure": "pres",
    "east": "u",
    "north": "v",
    "up": "w"


    
}

# %%
# add in attributes 
# define matadata for coorindates and variables - this will be the same for top and bottom sensor 
META_DATA = {
    "pres": {
        "long_name": "Pressure",
        "units": "dbar",
    },
    "abs_sal": {
        "long_name": "Absolute Salinity",
        "units": "g/kg",
    },
    "cons_temp": {
        "long_name": "Conservative Temperature",
        "units": "degree_Celsius",
    },
    "cons_temp_freezing": {
        "long_name": "Conservative Temperature Freezing",
        "units": "degree_Celsius",
    },
    "sigma0": {
        "long_name": "Potential Density Anomaly",
        "units": "kg/m3",
    },
    "theta": {
        "long_name": "Potential Temperature",
        "units": "degree_Celsius",
    },
    "sal": {
        "long_name": "Practical salinity",
        "units": "PSU",
    },
    "temp_freezing": {
        "long_name": "Temperature Freezing [ITS-90 deg C]",
        "units": "degree_Celsius",
    },
    "temp": {
        "long_name": "Temperature [ITS-90 deg C]",
        "units": "degree_Celsius",
    },
    "con": {
        "long_name": "Conductivity",
        "units": "S/m",
    },
    "z": {
        "long_name": "Depth",
        "units": "m",
        "description": "Depth is positive downward"
    },
    "lat": {
        "long_name": "Latitude",
        "units": "degrees_north",
    },
    "lon": {
        "long_name": "Longitude",
        "units": "degrees_east",
    },
    "u":{
        "long_name": "Eastward Velocity",
        "units": "cm/s",
    },
    "v":{
        "long_name": "Northward Velocity",
        "units": "cm/s",
    },
    "w": {
        "long_name": "Vertical Velocity",
        "units": "m/s",
    },
    "speed": {
        "long_name": "speed",
        "units": "cm/s",
    },
    "dir": {
        "long_name": "direction",
        "units": "degrees",
    },
    "mag_declination": {
        "long_name": "Magnetic Declination",
        "units": "degrees East",
        "description": "Angle between magnetic North and true North"
    },
    
    
}

# %%
for i in range(len(LDEO_datasets)):
    LDEO_datasets[i] = rename_vars_if_exist(LDEO_datasets[i], rename_map)

# %%
for v, attrs in META_DATA.items():
    for i in range(len(LDEO_datasets)):
        if v in LDEO_datasets[i]:
            LDEO_datasets[i][v].attrs.update(attrs)

# %%
LDEO_datasets[2]
# Out:
# <xarray.Dataset> Size: 2MB
# Dimensions:  (time: 38094)
# Coordinates:
#   * time     (time) datetime64[ns] 305kB 2017-02-01T12:00:00 ... 2018-03-05T0...
# Data variables:
#     u        (time) float64 305kB ...
#     v        (time) float64 305kB ...
#     w        (time) float64 305kB ...
#     pres     (time) float64 305kB ...
# Attributes:
#     Institution:     Lamont-Doherty Earth Observatory
#     Contact:         zappa@ldeo.columbia.edu, ukm2103@columbia.edu
#     DOI:             doi:10.7916/a4k3-0a14
#     Instrument:      Aquadopp Current Meter 2000 kHz
#     Location:        Terra Nova Bay, Antarctica
#     Mooring_coords:  74.97° S, 163.96° E
#     Units:           Velocity: m/s, Pressure:dbar
#     Depth:           370 m
#     Notes:           Horizontal current velocities should be multiplied by -c...

# %%
LDEO_20

# %%
LDEO_2017_ctd_bot_360
LDEO_2017_vel_bot_370

# %%
LDEO_datasets = [LDEO_2017_ctd_bot_360,LDEO_2017_vel_bot_370]

# %%
LDEO_datasets[0] = LDEO_datasets[0].assign_coords({'lat':-74.97,'lon':163.96})
LDEO_datasets[1] = LDEO_datasets[1].assign_coords({'lat':-74.97,'lon':163.96})

# %%
import sys
sys.path.append('/Users/mblan/Documents/research/TNB_tools/TNB_tools')
import magnetic_declination

# %%
mag_dec = 135.38

# %%
# correct velocity for magnetic declination 
magnetic_declination_radians = np.deg2rad(mag_dec)
u_prime, v_prime = magnetic_declination.rotate_velocity(LDEO_datasets[1].u,LDEO_datasets[1].v,-magnetic_declination_radians)

# %%
LDEO_datasets[1]['u'] = ('time', u_prime.data)
LDEO_datasets[1]['v'] = ('time', v_prime.data)

# %%
LDEO_dict = {
    "/": None,
    "2017/ctd/bot": LDEO_datasets[0],
    "2017/vel/bot": LDEO_datasets[1],
}

# %%
dt_LDEO = xr.DataTree.from_dict(LDEO_dict)

# %%
# try to make parent to combine the datatrees 
moorings = xr.DataTree(name="TNB Moorings")
moorings.children = {
    'DITD':dt_DITD,
    'DITN':dt_DITN,
    'DITS':dt_DITS,
    'TNBD':dt_TNBD,
    'P2': dt_P2,
    'P3': dt_P3,
    'D': dt_D,
    'LDEO': dt_LDEO,
    }

# %%
moorings.to_netcdf('TNB_Moorings_DataTree.nc')

# %%
print(moorings.keys())
# Out:
# KeysView(<xarray.DataTree 'TNB Moorings'>
# Group: /
# ├── Group: /DITD
# │   ├── Group: /DITD/2017
# │   │   ├── Group: /DITD/2017/vel
# │   │   │   └── Group: /DITD/2017/vel/bot
# │   │   │           Dimensions:  (time: 37488)
# │   │   │           Coordinates:
# │   │   │             * time     (time) datetime64[ns] 300kB 2017-02-08T20:30:00 ... 2018-03-06T0...
# │   │   │               z        int64 8B ...
# │   │   │               lat      float64 8B ...
# │   │   │               lon      float64 8B ...
# │   │   │           Data variables: (12/15)
# │   │   │               dir      (time) float64 300kB ...
# │   │   │               speed    (time) float64 300kB ...
# │   │   │               temp     (time) float64 300kB ...
# │   │   │               pres     (time) float64 300kB ...
# │   │   │               hdgt     (time) float64 300kB ...
# │   │   │               pitch    (time) float64 300kB ...
# │   │   │               ...       ...
# ...
